# %% [markdown]
# <a href="https://colab.research.google.com/github/Kawaguchi-2022/colab_linq_test/blob/main/sig_tanh_comp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
4.3.1.2 sigmoid - Keras (MNIST)
'''

import numpy as np
import tensorflow as tf
from tensorflow.keras import datasets
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


if __name__ == '__main__':
    np.random.seed(123)
    tf.random.set_seed(123)

    '''
    1. データの準備
    '''
    mnist = datasets.mnist
    (x_train, t_train), (x_test, t_test) = mnist.load_data()

    x_train = (x_train.reshape(-1, 784) / 255).astype(np.float32)
    x_test = (x_test.reshape(-1, 784) / 255).astype(np.float32)
    t_train = np.eye(10)[t_train].astype(np.float32)
    t_test = np.eye(10)[t_test].astype(np.float32)

    '''
    2. モデルの構築
    '''
    model = Sequential()
    model.add(Dense(200, activation='sigmoid'))
    model.add(Dense(200, activation='sigmoid'))
    model.add(Dense(200, activation='sigmoid'))
    model.add(Dense(10, activation='softmax'))

    '''
    3. モデルの学習
    '''
    model.compile(optimizer='sgd', loss='categorical_crossentropy',
                  metrics=['accuracy'])

    model.fit(x_train, t_train,
              epochs=30, batch_size=100,
              verbose=2)

    '''
    4. モデルの評価
    '''
    loss, acc = model.evaluate(x_test, t_test, verbose=0)
    print('test_loss: {:.3f}, test_acc: {:.3f}'.format(
        loss,
        acc
    ))
# Out:
# Epoch 1/30
# 600/600 - 2s - loss: 2.3080 - accuracy: 0.1128 - 2s/epoch - 3ms/step
# Epoch 2/30
# 600/600 - 1s - loss: 2.2951 - accuracy: 0.1269 - 1s/epoch - 2ms/step
# Epoch 3/30
# 600/600 - 1s - loss: 2.2906 - accuracy: 0.1348 - 1s/epoch - 2ms/step
# Epoch 4/30
# 600/600 - 1s - loss: 2.2851 - accuracy: 0.1572 - 1s/epoch - 2ms/step
# Epoch 5/30
# 600/600 - 1s - loss: 2.2785 - accuracy: 0.1749 - 1s/epoch - 2ms/step
# Epoch 6/30
# 600/600 - 1s - loss: 2.2700 - accuracy: 0.1965 - 1s/epoch - 2ms/step
# Epoch 7/30
# 600/600 - 1s - loss: 2.2588 - accuracy: 0.2350 - 1s/epoch - 2ms/step
# Epoch 8/30
# 600/600 - 1s - loss: 2.2427 - accuracy: 0.2677 - 1s/epoch - 2ms/step
# Epoch 9/30
# 600/600 - 1s - loss: 2.2189 - accuracy: 0.3403 - 1s/epoch - 2ms/step
# Epoch 10/30
# 600/600 - 1s - loss: 2.1813 - accuracy: 0.3750 - 1s/epoch - 2ms/step
# Epoch 11/30
# 600/600 - 1s - loss: 2.1185 - accuracy: 0.4156 - 1s/epoch - 2ms/step
# Epoch 12/30
# 600/600 - 1s - loss: 2.0167 - accuracy: 0.4405 - 1s/epoch - 2ms/step
# Epoch 13/30
# 600/600 - 1s - loss: 1.8730 - accuracy: 0.4895 - 1s/epoch - 2ms/step
# Epoch 14/30
# 600/600 - 1s - loss: 1.7061 - accuracy: 0.5275 - 1s/epoch - 2ms/step
# Epoch 15/30
# 600/600 - 1s - loss: 1.5347 - accuracy: 0.5748 - 1s/epoch - 2ms/step
# Epoch 16/30
# 600/600 - 1s - loss: 1.3727 - accuracy: 0.6098 - 1s/epoch - 2ms/step
# Epoch 17/30
# 600/600 - 1s - loss: 1.2298 - accuracy: 0.6383 - 1s/epoch - 2ms/step
# Epoch 18/30
# 600/600 - 1s - loss: 1.1093 - accuracy: 0.6643 - 1s/epoch - 2ms/step
# Epoch 19/30
# 600/600 - 1s - loss: 1.0125 - accuracy: 0.6862 - 1s/epoch - 2ms/step
# Epoch 20/30
# 600/600 - 1s - loss: 0.9381 - accuracy: 0.7065 - 1s/epoch - 2ms/step
# Epoch 21/30
# 600/600 - 1s - loss: 0.8812 - accuracy: 0.7212 - 1s/epoch - 2ms/step
# Epoch 22/30
# 600/600 - 1s - loss: 0.8364 - accuracy: 0.7358 - 1s/epoch - 2ms/step
# Epoch 23/30
# 600/600 - 1s - loss: 0.8003 - accuracy: 0.7488 - 1s/epoch - 2ms/step
# Epoch 24/30
# 600/600 - 1s - loss: 0.7693 - accuracy: 0.7599 - 1s/epoch - 2ms/step
# Epoch 25/30
# 600/600 - 1s - loss: 0.7424 - accuracy: 0.7702 - 1s/epoch - 2ms/step
# Epoch 26/30
# 600/600 - 1s - loss: 0.7180 - accuracy: 0.7789 - 1s/epoch - 2ms/step
# Epoch 27/30
# 600/600 - 1s - loss: 0.6953 - accuracy: 0.7883 - 1s/epoch - 2ms/step
# Epoch 28/30
# 600/600 - 1s - loss: 0.6740 - accuracy: 0.7971 - 1s/epoch - 2ms/step
# Epoch 29/30
# 600/600 - 1s - loss: 0.6537 - accuracy: 0.8053 - 1s/epoch - 2ms/step
# Epoch 30/30
# 600/600 - 1s - loss: 0.6339 - accuracy: 0.8130 - 1s/epoch - 2ms/step
# test_loss: 0.615, test_acc: 0.820

# %%
'''
4.3.1.2 tanh - Keras (MNIST)
'''

import numpy as np
import tensorflow as tf
from tensorflow.keras import datasets
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


if __name__ == '__main__':
    np.random.seed(123)
    tf.random.set_seed(123)

    '''
    1. データの準備
    '''
    mnist = datasets.mnist
    (x_train, t_train), (x_test, t_test) = mnist.load_data()

    x_train = (x_train.reshape(-1, 784) / 255).astype(np.float32)
    x_test = (x_test.reshape(-1, 784) / 255).astype(np.float32)
    t_train = np.eye(10)[t_train].astype(np.float32)
    t_test = np.eye(10)[t_test].astype(np.float32)

    '''
    2. モデルの構築
    '''
    model = Sequential()
    model.add(Dense(200, activation='tanh'))
    model.add(Dense(200, activation='tanh'))
    model.add(Dense(200, activation='tanh'))
    model.add(Dense(10, activation='softmax'))

    '''
    3. モデルの学習
    '''
    model.compile(optimizer='sgd', loss='categorical_crossentropy',
                  metrics=['accuracy'])

    model.fit(x_train, t_train,
              epochs=30, batch_size=100,
              verbose=2)

    '''
    4. モデルの評価
    '''
    loss, acc = model.evaluate(x_test, t_test, verbose=0)
    print('test_loss: {:.3f}, test_acc: {:.3f}'.format(
        loss,
        acc
    ))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# Epoch 1/30
# 600/600 - 4s - loss: 0.7965 - accuracy: 0.8083 - 4s/epoch - 6ms/step
# Epoch 2/30
# 600/600 - 1s - loss: 0.3959 - accuracy: 0.8894 - 1s/epoch - 2ms/step
# Epoch 3/30
# 600/600 - 1s - loss: 0.3380 - accuracy: 0.9038 - 1s/epoch - 2ms/step
# Epoch 4/30
# 600/600 - 1s - loss: 0.3083 - accuracy: 0.9117 - 1s/epoch - 2ms/step
# Epoch 5/30
# 600/600 - 1s - loss: 0.2881 - accuracy: 0.9171 - 1s/epoch - 2ms/step
# Epoch 6/30
# 600/600 - 1s - loss: 0.2721 - accuracy: 0.9219 - 1s/epoch - 2ms/step
# Epoch 7/30
# 600/600 - 1s - loss: 0.2591 - accuracy: 0.9260 - 1s/epoch - 2ms/step
# Epoch 8/30
# 600/600 - 1s - loss: 0.2471 - accuracy: 0.9292 - 1s/epoch - 2ms/step
# Epoch 9/30
# 600/600 - 1s - loss: 0.2364 - accuracy: 0.9327 - 1s/epoch - 2ms/step
# Epoch 10/30
# 600/600 - 1s - loss: 0.2263 - accuracy: 0.9356 - 1s/epoch - 2ms/step
# Epoch 11/30
# 600/600 - 1s - loss: 0.2165 - accuracy: 0.9383 - 1s/epoch - 2ms/step
# Epoch 12/30
# 600/600 - 1s - loss: 0.2078 - accuracy: 0.9409 - 1s/epoch - 2ms/step
# Epoch 13/30
# 600/600 - 1s - loss: 0.1991 - accuracy: 0.9431 - 1s/epoch - 2ms/step
# Epoch 14/30
# 600/600 - 1s - loss: 0.1911 - accuracy: 0.9454 - 1s/epoch - 2ms/step
# Epoch 15/30
# 600/600 - 1s - loss: 0.1835 - accuracy: 0.9475 - 1s/epoch - 2ms/step
# Epoch 16/30
# 600/600 - 1s - loss: 0.1764 - accuracy: 0.9499 - 1s/epoch - 2ms/step
# Epoch 17/30
# 600/600 - 1s - loss: 0.1697 - accuracy: 0.9512 - 1s/epoch - 2ms/step
# Epoch 18/30
# 600/600 - 1s - loss: 0.1636 - accuracy: 0.9535 - 1s/epoch - 2ms/step
# Epoch 19/30
# 600/600 - 1s - loss: 0.1576 - accuracy: 0.9551 - 1s/epoch - 2ms/step
# Epoch 20/30
# 600/600 - 1s - loss: 0.1522 - accuracy: 0.9564 - 1s/epoch - 2ms/step
# Epoch 21/30
# 600/600 - 1s - loss: 0.1471 - accuracy: 0.9578 - 1s/epoch - 2ms/step
# Epoch 22/30
# 600/600 - 1s - loss: 0.1422 - accuracy: 0.9596 - 1s/epoch - 2ms/step
# Epoch 23/30
# 600/600 - 1s - loss: 0.1376 - accuracy: 0.9606 - 1s/epoch - 2ms/step
# Epoch 24/30
# 600/600 - 1s - loss: 0.1332 - accuracy: 0.9618 - 1s/epoch - 2ms/step
# Epoch 25/30
# 600/600 - 1s - loss: 0.1290 - accuracy: 0.9631 - 1s/epoch - 2ms/step
# Epoch 26/30
# 600/600 - 1s - loss: 0.1252 - accuracy: 0.9643 - 1s/epoch - 2ms/step
# Epoch 27/30
# 600/600 - 1s - loss: 0.1212 - accuracy: 0.9646 - 1s/epoch - 2ms/step
# Epoch 28/30
# 600/600 - 1s - loss: 0.1177 - accuracy: 0.9664 - 1s/epoch - 2ms/step
# Epoch 29/30
# 600/600 - 1s - loss: 0.1144 - accuracy: 0.9674 - 1s/epoch - 2ms/step
# Epoch 30/30
# 600/600 - 1s - loss: 0.1109 - accuracy: 0.9681 - 1s/epoch - 2ms/step
# test_loss: 0.121, test_acc: 0.964

# %%
'''
4.3.2.2 ReLU - Keras (MNIST)
'''

import numpy as np
import tensorflow as tf
from tensorflow.keras import datasets
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense


if __name__ == '__main__':
    np.random.seed(123)
    tf.random.set_seed(123)

    '''
    1. データの準備
    '''
    mnist = datasets.mnist
    (x_train, t_train), (x_test, t_test) = mnist.load_data()

    x_train = (x_train.reshape(-1, 784) / 255).astype(np.float32)
    x_test = (x_test.reshape(-1, 784) / 255).astype(np.float32)
    t_train = np.eye(10)[t_train].astype(np.float32)
    t_test = np.eye(10)[t_test].astype(np.float32)

    '''
    2. モデルの構築
    '''
    model = Sequential()
    model.add(Dense(200, activation='relu'))
    model.add(Dense(200, activation='relu'))
    model.add(Dense(200, activation='relu'))
    model.add(Dense(10, activation='softmax'))

    '''
    3. モデルの学習
    '''
    model.compile(optimizer='sgd', loss='categorical_crossentropy',
                  metrics=['accuracy'])

    model.fit(x_train, t_train,
              epochs=30, batch_size=100,
              verbose=2)

    '''
    4. モデルの評価
    '''
    loss, acc = model.evaluate(x_test, t_test, verbose=0)
    print('test_loss: {:.3f}, test_acc: {:.3f}'.format(
        loss,
        acc
    ))
# Out:
# Epoch 1/30
# 600/600 - 2s - loss: 1.0757 - accuracy: 0.7334 - 2s/epoch - 3ms/step
# Epoch 2/30
# 600/600 - 1s - loss: 0.3961 - accuracy: 0.8888 - 1s/epoch - 2ms/step
# Epoch 3/30
# 600/600 - 1s - loss: 0.3233 - accuracy: 0.9068 - 1s/epoch - 2ms/step
# Epoch 4/30
# 600/600 - 1s - loss: 0.2868 - accuracy: 0.9174 - 1s/epoch - 2ms/step
# Epoch 5/30
# 600/600 - 1s - loss: 0.2615 - accuracy: 0.9242 - 1s/epoch - 2ms/step
# Epoch 6/30
# 600/600 - 1s - loss: 0.2406 - accuracy: 0.9311 - 1s/epoch - 2ms/step
# Epoch 7/30
# 600/600 - 1s - loss: 0.2238 - accuracy: 0.9360 - 1s/epoch - 2ms/step
# Epoch 8/30
# 600/600 - 1s - loss: 0.2085 - accuracy: 0.9406 - 1s/epoch - 2ms/step
# Epoch 9/30
# 600/600 - 1s - loss: 0.1955 - accuracy: 0.9437 - 1s/epoch - 2ms/step
# Epoch 10/30
# 600/600 - 1s - loss: 0.1838 - accuracy: 0.9475 - 1s/epoch - 2ms/step
# Epoch 11/30
# 600/600 - 1s - loss: 0.1730 - accuracy: 0.9500 - 1s/epoch - 2ms/step
# Epoch 12/30
# 600/600 - 1s - loss: 0.1636 - accuracy: 0.9524 - 1s/epoch - 2ms/step
# Epoch 13/30
# 600/600 - 1s - loss: 0.1547 - accuracy: 0.9558 - 1s/epoch - 2ms/step
# Epoch 14/30
# 600/600 - 1s - loss: 0.1468 - accuracy: 0.9574 - 1s/epoch - 2ms/step
# Epoch 15/30
# 600/600 - 1s - loss: 0.1393 - accuracy: 0.9604 - 1s/epoch - 2ms/step
# Epoch 16/30
# 600/600 - 1s - loss: 0.1325 - accuracy: 0.9621 - 1s/epoch - 2ms/step
# Epoch 17/30
# 600/600 - 1s - loss: 0.1259 - accuracy: 0.9643 - 1s/epoch - 2ms/step
# Epoch 18/30
# 600/600 - 1s - loss: 0.1205 - accuracy: 0.9662 - 1s/epoch - 2ms/step
# Epoch 19/30
# 600/600 - 1s - loss: 0.1149 - accuracy: 0.9679 - 1s/epoch - 2ms/step
# Epoch 20/30
# 600/600 - 1s - loss: 0.1099 - accuracy: 0.9693 - 1s/epoch - 2ms/step
# Epoch 21/30
# 600/600 - 1s - loss: 0.1053 - accuracy: 0.9700 - 1s/epoch - 2ms/step
# Epoch 22/30
# 600/600 - 1s - loss: 0.1009 - accuracy: 0.9716 - 1s/epoch - 2ms/step
# Epoch 23/30
# 600/600 - 1s - loss: 0.0967 - accuracy: 0.9727 - 1s/epoch - 2ms/step
# Epoch 24/30
# 600/600 - 1s - loss: 0.0929 - accuracy: 0.9742 - 1s/epoch - 2ms/step
# Epoch 25/30
# 600/600 - 1s - loss: 0.0893 - accuracy: 0.9748 - 1s/epoch - 2ms/step
# Epoch 26/30
# 600/600 - 1s - loss: 0.0860 - accuracy: 0.9759 - 1s/epoch - 2ms/step
# Epoch 27/30
# 600/600 - 1s - loss: 0.0825 - accuracy: 0.9770 - 1s/epoch - 2ms/step
# Epoch 28/30
# 600/600 - 1s - loss: 0.0795 - accuracy: 0.9780 - 1s/epoch - 2ms/step
# Epoch 29/30
# 600/600 - 1s - loss: 0.0766 - accuracy: 0.9787 - 1s/epoch - 2ms/step
# Epoch 30/30
# 600/600 - 1s - loss: 0.0737 - accuracy: 0.9797 - 1s/epoch - 2ms/step
# test_loss: 0.099, test_acc: 0.969

# %%
'''
4.3.3.2 Leaky ReLU - Keras (MNIST)
'''

import numpy as np
import tensorflow as tf
from tensorflow.keras import datasets
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU


if __name__ == '__main__':
    np.random.seed(123)
    tf.random.set_seed(123)

    '''
    1. データの準備
    '''
    mnist = datasets.mnist
    (x_train, t_train), (x_test, t_test) = mnist.load_data()

    x_train = (x_train.reshape(-1, 784) / 255).astype(np.float32)
    x_test = (x_test.reshape(-1, 784) / 255).astype(np.float32)
    t_train = np.eye(10)[t_train].astype(np.float32)
    t_test = np.eye(10)[t_test].astype(np.float32)

    '''
    2. モデルの構築
    '''
    model = Sequential()
    model.add(Dense(200))
    model.add(LeakyReLU(0.01))
    model.add(Dense(200))
    model.add(LeakyReLU(0.01))
    model.add(Dense(200))
    model.add(LeakyReLU(0.01))
    model.add(Dense(10, activation='softmax'))

    '''
    3. モデルの学習
    '''
    model.compile(optimizer='sgd', loss='categorical_crossentropy',
                  metrics=['accuracy'])

    model.fit(x_train, t_train,
              epochs=30, batch_size=100,
              verbose=2)

    '''
    4. モデルの評価
    '''
    loss, acc = model.evaluate(x_test, t_test, verbose=0)
    print('test_loss: {:.3f}, test_acc: {:.3f}'.format(
        loss,
        acc
    ))
# Out:
# Epoch 1/30
# 600/600 - 2s - loss: 1.0736 - accuracy: 0.7339 - 2s/epoch - 3ms/step
# Epoch 2/30
# 600/600 - 1s - loss: 0.3961 - accuracy: 0.8889 - 1s/epoch - 2ms/step
# Epoch 3/30
# 600/600 - 1s - loss: 0.3238 - accuracy: 0.9067 - 1s/epoch - 2ms/step
# Epoch 4/30
# 600/600 - 1s - loss: 0.2876 - accuracy: 0.9173 - 1s/epoch - 2ms/step
# Epoch 5/30
# 600/600 - 1s - loss: 0.2624 - accuracy: 0.9241 - 1s/epoch - 2ms/step
# Epoch 6/30
# 600/600 - 1s - loss: 0.2416 - accuracy: 0.9305 - 1s/epoch - 2ms/step
# Epoch 7/30
# 600/600 - 1s - loss: 0.2248 - accuracy: 0.9357 - 1s/epoch - 2ms/step
# Epoch 8/30
# 600/600 - 1s - loss: 0.2095 - accuracy: 0.9401 - 1s/epoch - 2ms/step
# Epoch 9/30
# 600/600 - 1s - loss: 0.1965 - accuracy: 0.9436 - 1s/epoch - 2ms/step
# Epoch 10/30
# 600/600 - 1s - loss: 0.1848 - accuracy: 0.9471 - 1s/epoch - 2ms/step
# Epoch 11/30
# 600/600 - 1s - loss: 0.1739 - accuracy: 0.9500 - 1s/epoch - 2ms/step
# Epoch 12/30
# 600/600 - 1s - loss: 0.1646 - accuracy: 0.9523 - 1s/epoch - 2ms/step
# Epoch 13/30
# 600/600 - 1s - loss: 0.1557 - accuracy: 0.9554 - 1s/epoch - 2ms/step
# Epoch 14/30
# 600/600 - 1s - loss: 0.1478 - accuracy: 0.9572 - 1s/epoch - 2ms/step
# Epoch 15/30
# 600/600 - 1s - loss: 0.1403 - accuracy: 0.9600 - 1s/epoch - 2ms/step
# Epoch 16/30
# 600/600 - 1s - loss: 0.1334 - accuracy: 0.9620 - 1s/epoch - 2ms/step
# Epoch 17/30
# 600/600 - 1s - loss: 0.1269 - accuracy: 0.9639 - 1s/epoch - 2ms/step
# Epoch 18/30
# 600/600 - 1s - loss: 0.1214 - accuracy: 0.9659 - 1s/epoch - 2ms/step
# Epoch 19/30
# 600/600 - 1s - loss: 0.1158 - accuracy: 0.9676 - 1s/epoch - 2ms/step
# Epoch 20/30
# 600/600 - 1s - loss: 0.1107 - accuracy: 0.9692 - 1s/epoch - 2ms/step
# Epoch 21/30
# 600/600 - 1s - loss: 0.1061 - accuracy: 0.9695 - 1s/epoch - 2ms/step
# Epoch 22/30
# 600/600 - 1s - loss: 0.1017 - accuracy: 0.9713 - 1s/epoch - 2ms/step
# Epoch 23/30
# 600/600 - 1s - loss: 0.0975 - accuracy: 0.9726 - 1s/epoch - 2ms/step
# Epoch 24/30
# 600/600 - 1s - loss: 0.0937 - accuracy: 0.9738 - 1s/epoch - 2ms/step
# Epoch 25/30
# 600/600 - 1s - loss: 0.0899 - accuracy: 0.9744 - 1s/epoch - 2ms/step
# Epoch 26/30
# 600/600 - 1s - loss: 0.0867 - accuracy: 0.9755 - 1s/epoch - 2ms/step
# Epoch 27/30
# 600/600 - 1s - loss: 0.0831 - accuracy: 0.9769 - 1s/epoch - 2ms/step
# Epoch 28/30
# 600/600 - 1s - loss: 0.0801 - accuracy: 0.9779 - 1s/epoch - 2ms/step
# Epoch 29/30
# 600/600 - 1s - loss: 0.0772 - accuracy: 0.9785 - 1s/epoch - 2ms/step
# Epoch 30/30
# 600/600 - 1s - loss: 0.0742 - accuracy: 0.9794 - 1s/epoch - 2ms/step
# test_loss: 0.099, test_acc: 0.969

# %%
'''
4.3.4.2 Swish - Keras (MNIST)
'''

import numpy as np
import tensorflow as tf
from tensorflow.keras import datasets
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU
from tensorflow.keras import backend as K


if __name__ == '__main__':
    np.random.seed(123)
    tf.random.set_seed(123)

    '''
    1. データの準備
    '''
    mnist = datasets.mnist
    (x_train, t_train), (x_test, t_test) = mnist.load_data()

    x_train = (x_train.reshape(-1, 784) / 255).astype(np.float32)
    x_test = (x_test.reshape(-1, 784) / 255).astype(np.float32)
    t_train = np.eye(10)[t_train].astype(np.float32)
    t_test = np.eye(10)[t_test].astype(np.float32)

    '''
    2. モデルの構築
    '''
    def swish(x, beta=1.):
        return x * K.sigmoid(beta * x)
        # return x * tf.nn.sigmoid(beta * x)  # こちらでもOK

    model = Sequential()
    model.add(Dense(200, activation=swish))
    model.add(Dense(200, activation=swish))
    model.add(Dense(200, activation=swish))
    model.add(Dense(10, activation='softmax'))

    '''
    3. モデルの学習
    '''
    model.compile(optimizer='sgd', loss='categorical_crossentropy',
                  metrics=['accuracy'])

    model.fit(x_train, t_train,
              epochs=30, batch_size=100,
              verbose=2)

    '''
    4. モデルの評価
    '''
    loss, acc = model.evaluate(x_test, t_test, verbose=0)
    print('test_loss: {:.3f}, test_acc: {:.3f}'.format(
        loss,
        acc
    ))
# Out:
# Epoch 1/30
# 600/600 - 2s - loss: 1.7584 - accuracy: 0.6071 - 2s/epoch - 3ms/step
# Epoch 2/30
# 600/600 - 1s - loss: 0.5266 - accuracy: 0.8582 - 1s/epoch - 2ms/step
# Epoch 3/30
# 600/600 - 1s - loss: 0.3866 - accuracy: 0.8899 - 1s/epoch - 2ms/step
# Epoch 4/30
# 600/600 - 1s - loss: 0.3439 - accuracy: 0.9012 - 1s/epoch - 2ms/step
# Epoch 5/30
# 600/600 - 1s - loss: 0.3201 - accuracy: 0.9075 - 1s/epoch - 2ms/step
# Epoch 6/30
# 600/600 - 1s - loss: 0.3007 - accuracy: 0.9142 - 1s/epoch - 2ms/step
# Epoch 7/30
# 600/600 - 1s - loss: 0.2860 - accuracy: 0.9179 - 1s/epoch - 2ms/step
# Epoch 8/30
# 600/600 - 1s - loss: 0.2731 - accuracy: 0.9219 - 1s/epoch - 2ms/step
# Epoch 9/30
# 600/600 - 1s - loss: 0.2613 - accuracy: 0.9254 - 1s/epoch - 2ms/step
# Epoch 10/30
# 600/600 - 1s - loss: 0.2503 - accuracy: 0.9294 - 1s/epoch - 2ms/step
# Epoch 11/30
# 600/600 - 1s - loss: 0.2400 - accuracy: 0.9318 - 1s/epoch - 2ms/step
# Epoch 12/30
# 600/600 - 1s - loss: 0.2299 - accuracy: 0.9339 - 1s/epoch - 2ms/step
# Epoch 13/30
# 600/600 - 1s - loss: 0.2204 - accuracy: 0.9381 - 1s/epoch - 2ms/step
# Epoch 14/30
# 600/600 - 1s - loss: 0.2113 - accuracy: 0.9395 - 1s/epoch - 2ms/step
# Epoch 15/30
# 600/600 - 1s - loss: 0.2023 - accuracy: 0.9427 - 1s/epoch - 2ms/step
# Epoch 16/30
# 600/600 - 1s - loss: 0.1940 - accuracy: 0.9452 - 1s/epoch - 2ms/step
# Epoch 17/30
# 600/600 - 1s - loss: 0.1857 - accuracy: 0.9469 - 1s/epoch - 2ms/step
# Epoch 18/30
# 600/600 - 1s - loss: 0.1790 - accuracy: 0.9492 - 1s/epoch - 2ms/step
# Epoch 19/30
# 600/600 - 1s - loss: 0.1717 - accuracy: 0.9509 - 1s/epoch - 2ms/step
# Epoch 20/30
# 600/600 - 1s - loss: 0.1656 - accuracy: 0.9524 - 1s/epoch - 2ms/step
# Epoch 21/30
# 600/600 - 1s - loss: 0.1603 - accuracy: 0.9546 - 1s/epoch - 2ms/step
# Epoch 22/30
# 600/600 - 1s - loss: 0.1543 - accuracy: 0.9557 - 1s/epoch - 2ms/step
# Epoch 23/30
# 600/600 - 1s - loss: 0.1493 - accuracy: 0.9572 - 1s/epoch - 2ms/step
# Epoch 24/30
# 600/600 - 1s - loss: 0.1446 - accuracy: 0.9588 - 1s/epoch - 2ms/step
# Epoch 25/30
# 600/600 - 1s - loss: 0.1398 - accuracy: 0.9594 - 1s/epoch - 2ms/step
# Epoch 26/30
# 600/600 - 1s - loss: 0.1359 - accuracy: 0.9608 - 1s/epoch - 2ms/step
# Epoch 27/30
# 600/600 - 1s - loss: 0.1315 - accuracy: 0.9620 - 1s/epoch - 2ms/step
# Epoch 28/30
# 600/600 - 1s - loss: 0.1281 - accuracy: 0.9634 - 1s/epoch - 2ms/step
# Epoch 29/30
# 600/600 - 1s - loss: 0.1242 - accuracy: 0.9644 - 1s/epoch - 2ms/step
# Epoch 30/30
# 600/600 - 1s - loss: 0.1200 - accuracy: 0.9655 - 1s/epoch - 2ms/step
# test_loss: 0.131, test_acc: 0.961
